# %% [markdown]
# # **둘째마당. 본격 실습! 데이터 갖고 놀기**

# %% [markdown]
# ## 파이썬 운영환경을 사전에 기본 점검하기

# %%
# 그래프 해상도 설정
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### import os 명령을 통하여 os안에 있는 기본명령을 사용할 수가 있다.
# - 기본 os 명령을 사용하려면 <font color='blue'>**import os**</font>명령을 사용한다.
# - *os.* 상태에서 **<탭>키**를 쳐서 부속된 속성(attribute)을 확인할 수가 있다.
# - **작업디렉토리변경(chdir), 작업디렉토리생성(mkdir)** 등 기본적인 작업이 가능하다.
# - 파이썬은 디렉토리(폴더) 주소를 판별할 때에 \은 \\로 나타내야 하고 /는 그냥 한개만 사용하면 된다.
#   - 따라서 리눅스와 파일을 주고받아야 할 경우 경로를 /로 표시해 두는 것이 좋다.

# %%
import os   # OS 명령을 기본 사용하기 위한 라이브러리  

os.getcwd()   # 내가 현재 어느 폴더에 위치해 있는 지를 표시
# Out:
# 'D:\\Python_Example\\data'

# %% [markdown]
# os.chdir('../Python_Example/data')    # 상대경로 이동
#
# os.getcwd()           # 내가 현재 어느 폴더에 위치해 있는 지를 표시

# %% [markdown]
# ### 파이썬 기본 경고메세지 처리(무시 OR 기본값) 하기

# %%
import warnings     # 파이썬 기본적인 경고메세지 처리하기     

warnings.filterwarnings(action='ignore')      # 기본적인 경고메세지 무시하기 
# warnings.filterwarnings(action='default')    # 기본적인 경고메세지 기본값으로 표시하기

# %% [markdown]
# ### 이 책에서 사용하는 소프트웨어 버전

# %% [markdown]
# #### xlrd에 대한 설치
# - 엑셀, csv를 주로 다루는 library
# - xlrd or xlswriter중 하나를 주로 사용한다.
# - 설치명령 : anaconda prompt에서 아래의 명령으로 한다.
#   - conda install xlrd

# %% [markdown]
# import sys
# print("Python 버전:", sys.version)
#
# import pandas as pd
# print("pandas 버전:", pd.__version__)
#
# import matplotlib as mpl
# print("matplotlib 버전:", mpl.__version__)
#
# import numpy as np
# print("NumPy 버전:", np.__version__)
#
# import xlrd as xld
# print("xlrd 버전:", xlrd.__version__)

# %%
import sys print("Python 버전:", sys.version)

import pandas as pd print("pandas 버전:", pd.version)

import matplotlib as mpl print("matplotlib 버전:", mpl.version)

import numpy as np print("NumPy 버전:", np.version)

import xlrd as xld print("xlrd 버전:", xlrd.version)
# Out:
#   Cell In[8], line 1
#     import sys print("Python 버전:", sys.version)
#                ^
# SyntaxError: invalid syntax

# %%
# !pip install xlrd
# Out:
# ...
#      ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#      ---------------------------------------- 96.5/96.5 kB 1.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### 장비에 설치된 Library Version 파악

# %%
 pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %% [markdown]
# # 04 데이터 프레임의 세계로!

# %% [markdown]
# ## 04-2 데이터 프레임 만들기 - 시험 성적 데이터를 만들어 보자!

# %% [markdown]
# ### 데이터 입력해 데이터 프레임 만들기

# %% [markdown]
# **1. `pandas` 패키지 로드하기**

# %%
import pandas as pd

# %% [markdown]
# **2. 데이터 프레임 만들기**

# %%
# 간단하게 DataFrame을 구성해 봅니다.   
df_new = pd.DataFrame({'성명' : ['박지영','최기봉','임요한','한은경','차영언','김휘진','원이슬'],
                       '영어' : [100,100,100,100,100,100,100],
                       '수학' : [75,80,78,85,92,60,50]})
df_new
# Out:
#     성명   영어  수학
# 0  박지영  100  75
# 1  최기봉  100  80
# 2  임요한  100  78
# 3  한은경  100  85
# 4  차영언  100  92
# 5  김휘진  100  60
# 6  원이슬  100  50

# %%
# 간단하게 Pandas DataFrame을 구성해 본다.  
# () -> {} -> dict type으로 자료를 넣는다.  

df_test = pd.DataFrame({'name': ['홍길동','홍길순'] ,     # ,반드시 라인의 끝에 표시한다.  
                        'sex' : ['남','여'],  
                        'age' : [40,38] 
                       })
df_test
# Out:
#   name sex  age
# 0  홍길동   남   40
# 1  홍길순   여   38

# %%
# 간단하게 DataFrame을 구성해 봅니다. 
df = pd.DataFrame({'name'    : ['김지훈', '이유진', '박동현', '김민지'],
                   'english' : [90, 80, 60, 70],
                   'math'    : [50, 60, 100, 20]})
df    # 4 * 3 matrix(배열) 형태로 자료가 생성되었다.  
      # row(가로) * column(세로)로 된 n차원 배열형태로 생성됨
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %% [markdown]
# ### 데이터 프레임으로 분석하기

# %% [markdown]
# #### 특정 변수의 값 추출하기

# %%
# df_new : 컬럼명을 한글로 주었다.  , 실전에서는 되도록이면 이렇게 하지 마시고 영문으로 주세요. 
df_new['영어']      # 성명
# Out:
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# 5    100
# 6    100
# Name: 영어, dtype: int64

# %%
# 컬럼명을 영문으로 주었다.  
df['english']
# Out:
# 0    90
# 1    80
# 2    60
# 3    70
# Name: english, dtype: int64

# %% [markdown]
# #### 변수의 값으로 합계 구하기

# %%
sum(df['english'])
# Out:
# 300

# %%
sum(df['math'])
# Out:
# 230

# %% [markdown]
# #### 변수의 값으로 평균 구하기

# %%
sum(df['english']) / 4  # 영어 점수 평균
# Out:
# 75.0

# %%
sum(df['math']) / 4     # 수학 점수 평균
# Out:
# 57.5

# %%
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %% [markdown]
# #### DataFrame의 특성을 파악

# %%
df_new
# Out:
#     성명   영어  수학
# 0  박지영  100  75
# 1  최기봉  100  80
# 2  임요한  100  78
# 3  한은경  100  85
# 4  차영언  100  92
# 5  김휘진  100  60
# 6  원이슬  100  50

# %%
# head : 상위 5행을 출력 
df_new.head()
# Out:
#     성명   영어  수학
# 0  박지영  100  75
# 1  최기봉  100  80
# 2  임요한  100  78
# 3  한은경  100  85
# 4  차영언  100  92

# %%
df_new.tail()
# Out:
#     성명   영어  수학
# 2  임요한  100  78
# 3  한은경  100  85
# 4  차영언  100  92
# 5  김휘진  100  60
# 6  원이슬  100  50

# %%
df_new.shape
# Out:
# (7, 3)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   성명      7 non-null      object
#  1   영어      7 non-null      int64
#  2   수학      7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df_new.describe()
# Out:
#           영어         수학
# count    7.0   7.000000
# mean   100.0  74.285714
# std      0.0  14.545495
# min    100.0  50.000000
# 25%    100.0  67.500000
# 50%    100.0  78.000000
# 75%    100.0  82.500000
# max    100.0  92.000000

# %% [markdown]
# #### 파이썬 자료
# . 기본자료구조 참고문서 : https://injo.tistory.com/26
# . 참고문서 : https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
# 컬럼명은 한글 보다는 영문으로 주도록 해보자 
sales = pd.DataFrame({"prod" : ['사과','배','수박'],         # 제품
                      "price" : [1800, 1500, 3000],          # 가격
                      "Qty" : [24,38,13]                     # 판내량 
                     })
sales
# Out:
#   prod  price  Qty
# 0   사과   1800   24
# 1    배   1500   38
# 2   수박   3000   13

# %%
### 가격평균과 판매량 평균을 구해보자 
- 평균가격 : avg_price
- 판매량 평균 : avg_qty
# Out:
#   Cell In[41], line 2
#     - 평균가격 : avg_price
#     ^
# SyntaxError: illegal target for annotation

# %%
avg_price = sum(sales['price'])/ 3      # 전체 가격 / 건수   = 제품의 평균가  
print('평균 가격(avg_price) 은 ? ', avg_price)
# Out:
# 평균 가격(avg_price) 은 ?  2100.0

# %%
avg_Qty = sum(sales['Qty'])/ 3         # 총판매수량 / 건수  = 평균판매수량 
print('평균 판매량(avg_Qty) 은 ? ',avg_Qty)
# Out:
# 평균 판매량(avg_Qty) 은 ?  25.0

# %% [markdown]
# ---
# ## 04-3 외부 데이터 이용하기 - 축적된 시험 성적 데이터를 불러오자!

# %% [markdown]
# ### 엑셀 파일 불러오기
# - 엑셀 파일을 읽어들이는 패키지 : xlrd
# - 파이썬에서 엑셀을 읽어서 처리하는 모듈 : pandas, xlrd, xlsxwriter를 주로 사용한다.
# - 관련문서 : https://blog.naver.com/PostView.nhn?blogId=youndok&logNo=222154627975
# - conda install xlrd

# %% [markdown]
# #### 1. 엑셀 파일 살펴보기

# %% [markdown]
# #### 2. 워킹 디렉터리에 엑셀 파일 삽입하기

# %% [markdown]
# #### 3. 엑셀 파일 불러오기

# %%
import os  

os.getcwd()
# Out:
# 'D:\\Python_Example\\data'

# %%
df_exam = pd.read_excel('../data/excel_exam.xlsx')  # 엑셀 파일을 불러와 df_exam에 할당
df_exam.head(10)                                     # 출력
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25
# 8   9       3    20       98       15
# 9  10       3    50       98       45

# %% [markdown]
# #### 4. 분석하기

# %%
# 영어의 합계점수 
sum(df_exam['english'])
# Out:
# 1698

# %%
# 영어의 평균점수 
sum(df_exam['english']) / 20
# Out:
# 84.9

# %%
# 과학의 합계점수 
sum(df_exam['science'])
# Out:
# 1189

# %%
# 과학의 평균점수 
sum(df_exam['science']) / 20
# Out:
# 59.45

# %%
# 변수의 값 개수 구하기
x = [1, 2, 3, 4, 5, 6, 7]
x
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
len(x)
# Out:
# 7

# %%
len(df_exam['english']) # 영어응시자수
# Out:
# 20

# %%
len(df_exam['science'])   # 과학응시자수
# Out:
# 20

# %%
# 데이터 프레임의 행 개수 구하기
df = pd.DataFrame({'a' : [1, 2, 3],
                   'b' : [4, 5, 6]})
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
len(df)
# Out:
# 3

# %%
len(df_exam)                          # df_exam의 행 개수 구하기
# Out:
# 20

# %%
sum(df_exam['english']) / len(df_exam)  # english 합계를 행 개수로 나누기
# Out:
# 84.9

# %%
sum(df_exam['science']) / len(df_exam)  # science 합계를 행 개수로 나누기
# Out:
# 59.45

# %% [markdown]
# #### 엑셀 파일의 첫 번째 행이 변수명이 아니라면?

# %%
df_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
df_exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %%
df_exam_novar = pd.read_excel('../data/excel_exam_novar.xlsx')  # 엑셀의 head정보가 없는 것을 읽어본다. 
df_exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
df_exam_novar = pd.read_excel('../data/excel_exam_novar.xlsx', header = None)
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %% [markdown]
# #### 엑셀 파일에 시트가 여러 개 있다면?

# %%
# Sheet1 시트의 데이터 불러오기
df_exam = pd.read_excel('../data/excel_exam.xlsx', sheet_name = 'Sheet1')
df_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
# Sheet2 시트의 데이터 불러오기
df_exam = pd.read_excel('../data/excel_exam.xlsx', sheet_name = 'Sheet2')
df_exam.head()
# Out:
#    id  nclass  math  english
# 0   1       1    50       98
# 1   2       1    60       97
# 2   3       1    45       86
# 3   4       1    30       98
# 4   5       2    25       80

# %%
# 세 번째 시트의 데이터 불러오기
# sheet_name에 index값을 넣업줄 수가 있는데 이때 index는 0부터 시작됨 

df_exam = pd.read_excel('../data/excel_exam.xlsx', sheet_name = 2)
df_exam.head()
# Out:
#    id  nclass  math
# 0   1       1    50
# 1   2       1    60
# 2   3       1    45
# 3   4       1    30
# 4   5       2    25

# %%
# 세 번째 시트의 데이터 불러오기
# sheet_name에 index값을 넣업줄 수가 있는데 이때 index는 0부터 시작됨 

df_exam = pd.read_excel('../data/2020_의료급여_주요통계표.xlsx', sheet_name = 6)
df_exam
# Out:
#                       제 1 표 Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0   연도별 보장기관 및 의료급여 수급권자 현황        NaN         NaN        NaN        NaN
# 1                       NaN        NaN         NaN        NaN        NaN
# 2                        구분       보장기관         NaN          계        NaN
# 3                       NaN        시군구         NaN          계        NaN
# 4                       NaN       연도말         연평균         연도말        연평균
# 5                      2008        242         242    1841339    1848446
# 6                      2009        242         242    1677237    1727453
# 7                      2010        244         243    1674396    1682874
# 8                      2011        244         244    1609481    1633585
# 9                      2012        244         244    1507044    1538618
# 10                     2013        244  244.333333    1458871    1487942
# 11                     2014        245         245    1440762    1451954
# ...

# %% [markdown]
# #### 엑셀의 여러 시트중 원하는 시트만 읽어오는 방법
# - 참고문서 :
#   - 기본설명시 참고 : https://codealone.tistory.com/43
#   - 참고문서 : https://velog.io/@inhwa1025/Python-pandas%EC%9D%98-readexcel-%EC%98%B5%EC%85%98-%EC%A0%95%EB%A6%AC

# %% [markdown]
# #### read_excel()의 지정 가능한 옵션 정리
# - read_excel(filename,
#   -	sheet_name = '서울',
#   -	header = None,
#   -	names = ['일시','평균','최저','최고'],
#   -	index_col = None,
#   - usecols = "C:F",
#   -	dtype = {'일시':str, '평균':float, '최저':float, '최고':float},
#   -	skiprows = 32,
#   -	nrows = 28,
#   - na_values = 'nan',
#   -	thousands = ',')
#
#
#   - sheet_name: 기본값 0.
#     - 시트의 인덱스 번호(int) 또는 시트의 이름(문자열)이 들어감.
#     - 리스트 값을 넣을 수 있음.
#     - None 설정 시 모든 시트 선택
#   - header: 어느 행(row)에 열(column)의 이름이 있는지 지정.
#     - 기본 값은 0으로 첫 번째 줄. None 설정 시 헤더가 없는 것으로 설정되어 첫 번째 줄부터 바로 데이터로 받아옴
#   - names: header가 None일 경우 열(column)의 이름을 지정해줌
#   - index_col: 각 행(row)의 이름이 위치한 열(column)을 지정. 기본값은 None
#   - usecols: 기본값은 None으로 모든 열을 다 불러옴. “A:E”, “A,C,F:H” 와 같이 원하는 열을 선택해 불러올 수 있음
#   - dtype: 각 열의 데이터 타입을 지정 가능
#   - skiprows: 엑셀을 읽을 때 첫줄(0)으로 부터 몇 줄을 건너뛸 지 지정
#   - nrow: 몇 줄을 읽을 지 지정
#   - na_values: 값이 없는 경우 어떤 str 등으로 넣을 지 지정
#   - thousands: 돈과 같이 천단위로 쉼표(,)로 구분된 문자를 변환하기 위해 천단위의 구분자가 무엇인지 지정

# %% [markdown]
# ### CSV 파일 불러오기

# %% [markdown]
# #### 1. 워킹 디렉터리에 CSV 파일 삽입하기

# %% [markdown]
# #### 2. CSV 파일 불러오기

# %%
df_csv_exam = pd.read_csv('../data/exam.csv')
df_csv_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ### 데이터 프레임을 CSV 파일로 저장하기

# %% [markdown]
# #### 1. 데이터 프레임 만들기

# %%
df_midterm = pd.DataFrame({'name'    : ['박지영','최기봉','임요한','한은경'],
                           'english' : [90, 80, 60, 70],
                           'math'    : [50, 60, 100, 20],
                           'nclass'  : [1, 1, 2, 2]})
df_midterm
# Out:
#   name  english  math  nclass
# 0  박지영       90    50       1
# 1  최기봉       80    60       1
# 2  임요한       60   100       2
# 3  한은경       70    20       2

# %% [markdown]
# #### 2. CSV 파일로 저장하기

# %%
df_midterm.to_csv('../data/output_newdata_lsw2.csv', encoding = 'cp949')


#df_midterm.to_csv('../data/output_newdata_lsw.csv')   # csv로 기본저장

# %%
df_csv_exam3 = pd.read_csv('../data/output_newdata_lsw2.csv', encoding = 'cp949')
df_csv_exam3
# Out:
#    Unnamed: 0 name  english  math  nclass
# 0           0  박지영       90    50       1
# 1           1  최기봉       80    60       1
# 2           2  임요한       60   100       2
# 3           3  한은경       70    20       2

# %%
df_midterm.to_csv('../data/output_newdata2.csv', index = False, encoding = 'cp949')

#df_midterm.to_csv('../data/output_newdata.csv', index = False)  # index를 제거하고 저장

# %%
df_csv_exam4 = pd.read_csv('../data/output_newdata2.csv', encoding = 'cp949')
df_csv_exam4
# Out:
#   name  english  math  nclass
# 0  박지영       90    50       1
# 1  최기봉       80    60       1
# 2  임요한       60   100       2
# 3  한은경       70    20       2

# %% [markdown]
# ---

# %% [markdown]
# ### 정리하기

# %%
# 1. 데이터 프레임 만들기
df = pd.DataFrame({'name'    : ['김지훈', '이유진', '박동현', '김민지'],
                   'english' : [90, 80, 60, 70],
                   'math'    : [50, 60, 100, 20]})
print('1. Dataframe df is ')
print(df) 
print(); print(); 

# 2.외부 데이터 이용하기

# 엑셀 파일 불러오기
df_exam = pd.read_excel('../Data/excel_exam.xlsx') 
print('2. excel_exam.xlsx을 읽어들인 Dataframe df_exam =  ')
print(df_exam)
print(); print(); 

# CSV 파일 불러오기
df_csv_exam = pd.read_csv('../Data/exam.csv')
print('3. exam.csv을 읽어들인 df_csv_exam의 상위 6행 =  ')
print(df_csv_exam.head())
print(); print(); 
 
# CSV 파일로 저장하기
df_midterm_csv = df_midterm.to_csv('../Data/output_newdata_new.csv', index = False)
df_exam_csv = pd.read_csv('../Data/exam.csv')
print('4. output_newdata.csv로 저장된 내용 중 상위 6행 =  ')
print(df_exam_csv.head())
print(); print();
# Out:
# 1. Dataframe df is
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20
#
#
# 2. excel_exam.xlsx을 읽어들인 Dataframe df_exam =
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# ...
