# %% [markdown]
# # 08 그래프 만들기

# %% [markdown]
# ## 파이썬 운영환경을 사전에 기본 점검하기

# %%
# 그래프 해상도 설정
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})
# %config InlineBackend.figure_format = 'retina'

# %%
# %%html
# <!--마크다운 표 정렬 설정-->
# <style> table {float:left} </style>
# Out:
# <!--마크다운 표 정렬 설정-->
# <style> table {float:left} </style>

# %% [markdown]
# ### import os 명령을 통하여 os안에 있는 기본명령을 사용할 수가 있다.
# - 기본 os 명령을 사용하려면 <font color='blue'>**import os**</font>명령을 사용한다.
# - *os.* 상태에서 **<탭>키**를 쳐서 부속된 속성(attribute)을 확인할 수가 있다.
# - **작업디렉토리변경(chdir), 작업디렉토리생성(mkdir)** 등 기본적인 작업이 가능하다.
# - 파이썬은 디렉토리(폴더) 주소를 판별할 때에 \은 \\로 나타내야 하고 /는 그냥 한개만 사용하면 된다.
#   - 따라서 리눅스와 파일을 주고받아야 할 경우 경로를 /로 표시해 두는 것이 좋다.

# %%
import os   # OS 명령을 기본 사용하기 위한 라이브러리  

os.getcwd()   # 내가 현재 어느 폴더에 위치해 있는 지를 표시
# Out:
# 'C:\\Users\\A\\python_Data\\data'

# %%
os.chdir('../python_Data/data')   # 상대경로 이동 

os.getcwd()           # 내가 현재 어느 폴더에 위치해 있는 지를 표시
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 os.chdir('../python_Data/data')   # 상대경로 이동
#       3 os.getcwd()
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '../python_Data/data'

# %% [markdown]
# ### 파이썬 기본 경고메세지 처리(무시 OR 기본값) 하기

# %%
import warnings     # 파이썬 기본적인 경고메세지 처리하기     

warnings.filterwarnings(action='ignore')      # 기본적인 경고메세지 무시하기 
# warnings.filterwarnings(action='default')    # 기본적인 경고메세지 기본값으로 표시하기

# %% [markdown]
# ### 이 책에서 사용하는 소프트웨어 버전

# %%
import sys
print("Python 버전:", sys.version)

import numpy as np
print("NumPy 버전:", np.__version__) 

import pandas as pd
print("pandas 버전:", pd.__version__)

import matplotlib
print("matplotlib 버전:", matplotlib.__version__)

import seaborn as sns  
print("Seaborn 버전:", sns.__version__) 

import sklearn as skl 
print("scikit-learn 버전:", skl.__version__)
# Out:
# Python 버전: 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
# NumPy 버전: 1.24.3
# pandas 버전: 2.1.1
# matplotlib 버전: 3.7.2
# Seaborn 버전: 0.12.2
# scikit-learn 버전: 1.3.0

# %% [markdown]
# ## 08-1 파이썬으로 만들 수 있는 그래프 살펴보기

# %% [markdown]
# ## 08-2 산점도 - 변수 간 관계 표현하기
# - x축과 y축에 점으로 표현한 그래프 형태
# - 나이와 소득처럼 연속된 값으로 된 두 변수의 관계를 표현 할 때 사용합니다.

# %% [markdown]
# ### 산점도 만들기

# %%
import pandas as pd
mpg = pd.read_csv('../data/mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
패키지에는 다양한 함수 기능 뿐만 아니라 이 기능을 테스트 할 수 있는 예제 데이터가 들어 있는데요,

 mpg(Mile Per Gallon) 데이터는 미국 환경 보호국(US Environmental Protection Agency)에서 공개한 
자료로, 1999~2008년 사이 미국에서 출시된 자동차 234종의 연비 관련 정보를 담고 있습니다.
manufacturer : 자동차 제조사
model : 차기종
displ : 배기량
yeal : 제조년도
cyl : 실린더 수
trans : 변속기
drv : 구동 방식(f = 전륜구동, r = 후륜구동, 4 = 사륜구동)
city : 도시 연비
hwy : 고속도로 연비
fl : 연료 종류
class : 자동차 종류
# Out:
#   Cell In[7], line 4
#     자료로, 1999~2008년 사이 미국에서 출시된 자동차 234종의 연비 관련 정보를 담고 있습니다.
#                  ^
# SyntaxError: invalid decimal literal

# %%
# x축은 displ, y축은 hwy를 나타낸 산점도 만들기
# displ : 배기량

import seaborn as sns

sns.scatterplot(data = mpg, x = 'displ', y = 'hwy')
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>

# %% [markdown]
# #### 축 범위 설정하기

# %%
# x축 범위 3~6으로 제한
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy') \
   .set(xlim = [3, 6])
# Out:
# [(3.0, 6.0)]

# %%
# x축 범위 3~6, y축 범위 10~30으로 제한
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy') \
   .set(xlim = [3, 6], ylim = [10, 30])
# Out:
# [(3.0, 6.0), (10.0, 30.0)]

# %% [markdown]
# #### 종류별로 표식 색깔 바꾸기

# %%
# drv별로 표식 색깔 다르게 표현
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy', hue = 'drv')
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>

# %% [markdown]
# ------------------------------------------------------------------------
#
# #### (알아 두면 좋아요) 그래프 활용하기
#
# **그래프 설정 바꾸기**

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'figure.dpi' : '150'})             # 해상도, 기본값 72
plt.rcParams.update({'figure.figsize' : [8, 6]})        # 그림 크기, 기본값 [6, 4]
plt.rcParams.update({'font.size' : '12'})               # 글자 크기, 기본값 10
plt.rcParams.update({'font.family' : 'Malgun Gothic'})  # 폰트, 기본값 sans-serif

# %%
plt.rcParams.update({'figure.dpi'     : '150',  
                     'figure.figsize' : [8, 6],
                     'font.size'      : '12',
                     'font.family'    : 'Malgun Gothic'})

# %% [markdown]
# **설정 되돌리기**

# %%
# 모든 설정 되돌리기
# plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# **설명 메시지 숨기기**

# %%
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy');

# %%
# 그래프 해상도 재설정
plt.rcParams.update({'figure.dpi' : '100'})

# %% [markdown]
# ## 08-3 막대 그래프 - 집단 간 차이 표현하기

# %% [markdown]
# ### 평균 막대 그래프 만들기

# %% [markdown]
# #### 1. 집단별 평균표 만들기

# %%
df_mpg = mpg.groupby('drv') \
            .agg(mean_hwy = ('hwy', 'mean'))
df_mpg
# Out:
#       mean_hwy
# drv
# 4    19.174757
# f    28.160377
# r    21.000000

# %%
# drv별 분리
# hwy 평균 구하기
df_mpg = mpg.groupby('drv', as_index = False) \
            .agg(mean_hwy = ('hwy', 'mean'))
df_mpg
# Out:
#   drv   mean_hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %% [markdown]
# #### 2. 그래프 만들기

# %%
sns.barplot(data = df_mpg, x = 'drv', y = 'mean_hwy')
# Out:
# <Axes: xlabel='drv', ylabel='mean_hwy'>

# %% [markdown]
# #### 3. 크기순으로 정렬하기

# %%
# 데이터 프레임 정렬하기
df_mpg = df_mpg.sort_values('mean_hwy', ascending = False)
print(df_mpg)

# 막대 그래프 만들기
sns.barplot(data = df_mpg, x = 'drv', y = 'mean_hwy')
# Out:
#   drv   mean_hwy
# 1   f  28.160377
# 2   r  21.000000
# 0   4  19.174757
# <Axes: xlabel='drv', ylabel='mean_hwy'>

# %% [markdown]
# ### 빈도 막대 그래프 만들기
#
# #### 1. 집단별 빈도표 만들기

# %%
# 집단별 빈도표 만들기
df_mpg = mpg.groupby('drv', as_index = False) \
            .agg(n = ('drv', 'count'))

df_mpg
# Out:
#   drv    n
# 0   4  103
# 1   f  106
# 2   r   25

# %%
df_mpg2 = mpg.groupby('category', as_index = False) \
            .agg(n = ('category', 'count'))

df_mpg2
# Out:
#      category   n
# 0     2seater   5
# 1     compact  47
# 2     midsize  41
# 3     minivan  11
# 4      pickup  33
# 5  subcompact  35
# 6         suv  62

# %%
df_mpg3 = mpg.groupby('model', as_index = False) \
            .agg(n = ('model', 'count'))

df_mpg3
# Out:
#                      model   n
# 0              4runner 4wd   6
# 1                       a4   7
# 2               a4 quattro   8
# 3               a6 quattro   3
# 4                   altima   6
# 5       c1500 suburban 2wd   5
# 6                    camry   7
# 7             camry solara   7
# 8              caravan 2wd  11
# 9                    civic   9
# 10                 corolla   5
# 11                corvette   5
# 12       dakota pickup 4wd   9
# 13             durango 4wd   7
# 14          expedition 2wd   3
# 15            explorer 4wd   6
# 16         f150 pickup 4wd   7
# 17            forester awd   6
# 18      grand cherokee 4wd   8
# 19              grand prix   5
# 20                     gti   5
# 21             impreza awd   8
# 22                   jetta   9
# 23         k1500 tahoe 4wd   4
# 24  land cruiser wagon 4wd   2
# 25                  malibu   5
# 26                  maxima   3
# 27         mountaineer 4wd   4
# 28                 mustang   9
# ...

# %% [markdown]
# #### 2. 그래프 만들기

# %%
# 막대 그래프 만들기
sns.barplot(data = df_mpg, x = 'drv', y = 'n')
# Out:
# <Axes: xlabel='drv', ylabel='n'>

# %%
# 막대 그래프 만들기
sns.barplot(data = df_mpg2, x = 'category', y = 'n')
# Out:
# <Axes: xlabel='category', ylabel='n'>

# %%
# 막대 그래프 만들기
sns.barplot(data = df_mpg3, x = 'model', y = 'n')
# Out:
# <Axes: xlabel='model', ylabel='n'>

# %% [markdown]
# #### sns.countplot()으로 빈도 막대 그래프 만들기

# %%
# 빈도 막대 그래프 만들기
sns.countplot(data = mpg, x = 'drv')
# Out:
# <Axes: xlabel='drv', ylabel='count'>

# %%
# 빈도 막대 그래프 만들기
sns.countplot(data = mpg, x = 'category')
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
# 빈도 막대 그래프 만들기
sns.countplot(data = mpg, x = 'model')
# Out:
# <Axes: xlabel='model', ylabel='count'>

# %%
#변수의 고유값 출력 

mpg['drv'].unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %%
mpg['category'].unique()
# Out:
# array(['compact', 'midsize', 'suv', '2seater', 'minivan', 'pickup',
#        'subcompact'], dtype=object)

# %%
#출력할 내용을 알파벳순으로 정렬하여 보여줍니다.

mpg['model'].unique()
# Out:
# array(['a4', 'a4 quattro', 'a6 quattro', 'c1500 suburban 2wd', 'corvette',
#        'k1500 tahoe 4wd', 'malibu', 'caravan 2wd', 'dakota pickup 4wd',
#        'durango 4wd', 'ram 1500 pickup 4wd', 'expedition 2wd',
#        'explorer 4wd', 'f150 pickup 4wd', 'mustang', 'civic', 'sonata',
#        'tiburon', 'grand cherokee 4wd', 'range rover', 'navigator 2wd',
#        'mountaineer 4wd', 'altima', 'maxima', 'pathfinder 4wd',
#        'grand prix', 'forester awd', 'impreza awd', '4runner 4wd',
#        'camry', 'camry solara', 'corolla', 'land cruiser wagon 4wd',
#        'toyota tacoma 4wd', 'gti', 'jetta', 'new beetle', 'passat'],
#       dtype=object)

# %%
df_mpg['drv'].unique()
# Out:
# array(['4', 'f', 'r'], dtype=object)

# %%
df_mpg2['category'].unique()
# Out:
# array(['2seater', 'compact', 'midsize', 'minivan', 'pickup', 'subcompact',
#        'suv'], dtype=object)

# %%
df_mpg3['model'].unique()
# Out:
# array(['4runner 4wd', 'a4', 'a4 quattro', 'a6 quattro', 'altima',
#        'c1500 suburban 2wd', 'camry', 'camry solara', 'caravan 2wd',
#        'civic', 'corolla', 'corvette', 'dakota pickup 4wd', 'durango 4wd',
#        'expedition 2wd', 'explorer 4wd', 'f150 pickup 4wd',
#        'forester awd', 'grand cherokee 4wd', 'grand prix', 'gti',
#        'impreza awd', 'jetta', 'k1500 tahoe 4wd',
#        'land cruiser wagon 4wd', 'malibu', 'maxima', 'mountaineer 4wd',
#        'mustang', 'navigator 2wd', 'new beetle', 'passat',
#        'pathfinder 4wd', 'ram 1500 pickup 4wd', 'range rover', 'sonata',
#        'tiburon', 'toyota tacoma 4wd'], dtype=object)

# %% [markdown]
# **막대 정렬하기**

# %%
# 4, f, r 순으로 막대 정렬, 원하는 순서를 미리 지정하여 출력을 합니다.
sns.countplot(data = mpg, x = 'drv', order = ['4', 'f', 'r'])
# Out:
# <Axes: xlabel='drv', ylabel='count'>

# %%
# drv의 값을 빈도가 높은 순으로 출력
mpg['drv'].value_counts().index
# Out:
# Index(['f', '4', 'r'], dtype='object', name='drv')

# %%
# drv의 값을 빈도가 높은 순으로 출력
df_mpg2['category'].value_counts().index
# Out:
# Index(['2seater', 'compact', 'midsize', 'minivan', 'pickup', 'subcompact',
#        'suv'],
#       dtype='object', name='category')

# %%
# drv의 값을 빈도가 높은 순으로 출력
df_mpg3['model'].value_counts().index
# Out:
# Index(['4runner 4wd', 'mustang', 'impreza awd', 'jetta', 'k1500 tahoe 4wd',
#        'land cruiser wagon 4wd', 'malibu', 'maxima', 'mountaineer 4wd',
#        'navigator 2wd', 'a4', 'new beetle', 'passat', 'pathfinder 4wd',
#        'ram 1500 pickup 4wd', 'range rover', 'sonata', 'tiburon', 'gti',
#        'grand prix', 'grand cherokee 4wd', 'forester awd', 'a4 quattro',
#        'a6 quattro', 'altima', 'c1500 suburban 2wd', 'camry', 'camry solara',
#        'caravan 2wd', 'civic', 'corolla', 'corvette', 'dakota pickup 4wd',
#        'durango 4wd', 'expedition 2wd', 'explorer 4wd', 'f150 pickup 4wd',
#        'toyota tacoma 4wd'],
#       dtype='object', name='model')

# %%
# drv 빈도 높은 순으로 막대 정렬
sns.countplot(data = mpg, x = 'drv', order = mpg['drv'].value_counts().index)
# Out:
# <Axes: xlabel='drv', ylabel='count'>

# %% [markdown]
# ## 08-4 선 그래프 - 시간에 따라 달라지는 데이터 표현하기

# %% [markdown]
# ### 시계열 그래프 만들기

# %%
# economics  Data  
     date : 연월일 
 1   pce           
 2   pop          
 3   psavert : 개인저축율         
 4   uempmed          
 5   unemploy : 실업자수          
 6   date2

# %%
# economics 데이터 불러오기
economics = pd.read_csv('../data/economics.csv')
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066

# %%
sns.lineplot(data = economics, x = 'date', y = 'unemploy')
# Out:
# <Axes: xlabel='date', ylabel='unemploy'>

# %% [markdown]
# #### x축에 연도 표시하기

# %% [markdown]
# **(1) 날짜 시간 타입 변수 만들기**

# %%
# 날짜 시간 타입 변수 만들기
economics['date2'] = pd.to_datetime(economics['date'])

# 변수 타입 확인
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
#  6   date2     574 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 31.5+ KB

# %%
economics[['date', 'date2']]
# Out:
#            date      date2
# 0    1967-07-01 1967-07-01
# 1    1967-08-01 1967-08-01
# 2    1967-09-01 1967-09-01
# 3    1967-10-01 1967-10-01
# 4    1967-11-01 1967-11-01
# ..          ...        ...
# 569  2014-12-01 2014-12-01
# 570  2015-01-01 2015-01-01
# 571  2015-02-01 2015-02-01
# 572  2015-03-01 2015-03-01
# 573  2015-04-01 2015-04-01
#
# [574 rows x 2 columns]

# %%
# 연 추출 => 1967~2015(48년간 데이터 확인)
economics['date2'].dt.year
# Out:
# 0      1967
# 1      1967
# 2      1967
# 3      1967
# 4      1967
#        ...
# 569    2014
# 570    2015
# 571    2015
# 572    2015
# 573    2015
# Name: date2, Length: 574, dtype: int32

# %%
# 월 추출 => 1~12월의 데이터 
economics['date2'].dt.month
# Out:
# 0       7
# 1       8
# 2       9
# 3      10
# 4      11
#        ..
# 569    12
# 570     1
# 571     2
# 572     3
# 573     4
# Name: date2, Length: 574, dtype: int32

# %%
# 일 추출 => 매월 1일자 데이터 생성한 것으로 보임.
economics['date2'].dt.day
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 569    1
# 570    1
# 571    1
# 572    1
# 573    1
# Name: date2, Length: 574, dtype: int32

# %% [markdown]
# **(2) 연도 변수 만들기**

# %%
# 연도 변수 추가
economics['year'] = economics['date2'].dt.year
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy      date2  year
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01  1967
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01  1967
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01  1967
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01  1967
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01  1967

# %% [markdown]
# **(3) x축에 연도 표시하기**

# %%
# x축에 연도 표시
sns.lineplot(data = economics, x = 'year', y = 'unemploy')
# Out:
# <Axes: xlabel='year', ylabel='unemploy'>

# %%
# 신뢰구간 제거
sns.lineplot(data = economics, x = 'year', y = 'unemploy', ci = None)
# Out:
# <Axes: xlabel='year', ylabel='unemploy'>

# %% [markdown]
# ## 08-5 상자 그림(boxplot) - 집단 간 분포 차이 표현하기
# - 데이터 분포 또는 퍼져 있는 형태를 지닙니다,

# %% [markdown]
# ### 상자 그림 만들기

# %%
import pandas as pd
import seaborn as sns

mpg = pd.read_csv('../data/mpg.csv')

sns.boxplot(data = mpg, x = 'drv', y = 'hwy')
# Out:
# <Axes: xlabel='drv', ylabel='hwy'>

# %% [markdown]
# ------------------------------------------------------------------------
#
# #### (알아 두면 좋아요) `seaborn` 더 알아보기
#
# **한글 표현하기**

# %%
# 맑은 고딕 폰트 설정
import matplotlib.pyplot as plt
plt.rcParams.update({'font.family' : 'Malgun Gothic'})

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ### 정리하기
#
# | seaborn 함수      | 그래프                    |
# |-------------------|---------------------------|
# | sns.scatterplot() | 산점도                    |
# | sns.barplot()     | 막대 그래프 - 요약표 활용 |
# | sns.countplot()   | 막대 그래프 - 원자료 활용 |
# | sns.lineplot()    | 선 그래프                 |
# | sns.boxplot()     | 상자 그림                 |

# %%
### 1. 산점도
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy')

# 축 제한
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy') \
   .set(xlim = [3, 6], ylim = [10, 50])

# 종류별로 표식 색깔 바꾸기
sns.scatterplot(data = mpg, x = 'displ', y = 'hwy', hue = 'drv')


### 2. 막대 그래프

## 평균 막대 그래프

# 1단계. 평균표 만들기
df_mpg = mpg.groupby('drv', as_index = False) \
            .agg(mean_hwy = ('hwy', 'mean'))

# 2단계. 그래프 만들기
sns.barplot(data = df_mpg, x = 'drv', y = 'mean_hwy')

## 빈도 막대 그래프
sns.countplot(data = mpg, x = 'drv')


### 3. 선 그래프
sns.lineplot(data = economics, x = 'date', y = 'unemploy')


### 4. 상자 그림
sns.boxplot(data = mpg, x = 'drv', y = 'hwy')
# Out:
# <Axes: xlabel='drv', ylabel='hwy'>
